# %%
import numpy as np
import bokeh.io
import bokeh.plotting
import scipy 
import colorcet
import panel as pn
import math
from bokeh.io import export_png
import holoviews as hv
from bokeh.io import export_svg
from sympy.solvers import solve

bokeh.io.output_notebook()
# Set up color palette for this notebook
colors = colorcet.b_glasbey_category10

pn.extension()
Rim4_tau_slider = pn.widgets.FloatSlider(
    name="Rim4 τ", start=0, end=10, step=0.01, value=0.2
)
Rim4_T_slider = pn.widgets.FloatSlider(
    name="Rim4 T", start=20, end=100, step=1, value=20
)

@pn.depends(
    Rim4_tau_slider.param.value,
    Rim4_T_slider.param.value,
   
)

def Rim4_plot(
    Rim4_tau=0.2,
    Rim4_T=20,
    t_max=140,
):
    args = (
        Rim4_tau,
        Rim4_T,
    )
  
    t = np.linspace(0, t_max, 400)
    Rim4 = (1-np.tanh(Rim4_tau*(t-Rim4_T)))/2
    Rim4Slow = (1-np.tanh(Rim4_tau*(t-43)))/2


    # Set up plot
    p = bokeh.plotting.figure(
        x_axis_label="Time (minutes)",
        y_axis_label="mRNA-Rim4 Complex Concentration (a.u.)",
        x_range=[0, t_max],
    )

      # Populate glyphs
    p.line(t, Rim4, line_width=2, color=colors[1], legend_label="Wildtype")
    p.line(t, Rim4Slow, line_width=2, color=colors[69], legend_label="Slow Degradation")

    

    # Place the legend
    p.legend.location = "top_right"
    p.xaxis.axis_label_text_font_size = "14pt"
    p.yaxis.axis_label_text_font_size = "14pt"
    p.yaxis.major_label_text_font_size = '12pt'
    p.xaxis.major_label_text_font_size = '11pt'

    return p

widgets = pn.Column(
    pn.Spacer(height=10),
    Rim4_tau_slider,
    Rim4_T_slider,
    width=150,
)

left_column = pn.Column(
    pn.Row(pn.Spacer(width=30)), Rim4_plot,
)

# Final layout
pn.Row(left_column, pn.Spacer(width=20), widgets)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b2e9f742-0758-4948-979b-d21449766bae">Loading BokehJS ...</span>
#     </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='da70e25c-9847-4080-bab2-b77fb9975353'>
#   <div id="fe0db66f-e97c-417b-9504-069f7c42102a" data-root-id="da70e25c-9847-4080-bab2-b77fb9975353" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"69588882-60d2-4d0f-9b37-49a27ff8c3d0":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"da70e25c-9847-4080-bab2-b77fb9975353"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"45b623d2-0595-4b15-bb0f-8304bd27dea3","attributes":{"plot_id":"da70e25c-9847-4080-bab2-b77fb9975353","comm_id":"e6c89cfc2e904326b1fc71d8a2609f27","client_comm_id":"661fdf6b5d2a4e609af44a93ed8eb8fb"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"69588882-60d2-4d0f-9b37-49a27ff8c3d0","roots":{"da70e25c-9847-4080-bab2-b77fb9975353":"fe0db66f-e97c-417b-9504-069f7c42102a"},"root_ids":["da70e25c-9847-4080-bab2-b77fb9975353"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Row
#     [0] Column
#         [0] Row
#             [0] Spacer(width=30)
#         [1] ParamFunction(function, _pane=Bokeh, defer_load=False)
#     [1] Spacer(width=20)
#     [2] Column(width=150)
#         [0] Spacer(height=10)
#         [1] FloatSlider(end=10, name='Rim4 τ', step=0.01, value=0.2)
#         [2] FloatSlider(end=100, name='Rim4 T', start=20, step=1, value=20)

# %%
#--------Rate constants---------
#(In terms of protein numbers: )

   

V = 10**(-11); 
NA = 6.023*10**(23);
vna = V*NA*(100*10**(-9))*10**(-3); 
ivna = 1/vna;

#(Clb4)

kClb4s = 0.0008;
kClb4sp = 0.009;
kClb4d = 0.02;
kClb4dp = 0.2;
kClb4dpp = 0.02;

#(Clb1)

kClb1s = 0.04;
kClb1sp = 0.024;
kClb1d = 0.1;
kClb1dp = 0.5;
kClb1dpp = 0.02;

#(Clb3)

kClb3s = 0.002;
kClb3sp = 0.000114;
kClb3d = 0.34;
kClb3dp = 0.2;
kClb3dpp = 0.02;
AlphaClb3 = 0.4;


#(Cdc20)

kCdc20s = 0.1;
kCdc20sp = 0.001;
kCdc20d = 0.05;
kCdc20dp = 0.02; 
kClb1Cdc20d = 0.8;
kClb4Cdc20d = 0.2;
kClb3Cdc20d = 0.4;


#(New model in progress: Includes APC, Cdc20 phosophorylation and binding )

kApcCdc20a = 0.25;
kApcCdc20d = 0.32;
JApcCdc20a = 0.1;
JApcCdc20d = 0.1;
kApcClb = 0.09;
JApcClb = 0.001;
kApcp = 0.072; 
JApcp = 0.01;
APCtot = 5*vna;

#(Cdc5)

kCdc5a = 0.1;
kCdc5i = 2;
kCdc5d = 0.04;
kCdc5dp = 0.003;
kCdc5dpp = 0.002;
kCdc5ap = 1.2;
kCdc5app = 2;
kCdc5s = 0.004; kCdc5sp = 0.027;

#(Ndt80)

kNdt80s = 0.01;
kNdt80sp = 2;
kNdt80d = 0.093;
kNdt80dp = 0.013; 
JNdt80c = 204 ;

#(Ama1)

kAma1i = 0.005;
kAma1ip = 0.5;
JAma1 = 0.1;
kAma1a = 0.1;
kAma1s = 0.01;
kAma1dp = 0.02;
AlphakAma1s = 0.4;


#( Modify Ndt80 autoregulation )

def Jfunc(x): 
    J=5*10*JNdt80c*(1 + (x/(5*vna)))/(x/(5*vna))/2
    return J

def Rim4(t,Rim4_tau, Rim4_T):
    R4 = (1-np.tanh(Rim4_tau*(t-Rim4_T)))/2
    return R4
  
def Meiosis_ODE(Odes, t, Rim4_tau, Rim4_T):
    
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N = Odes


    # Compute dOdes/dt
    dClb1_dt = 1.0*(kClb1s*vna + kClb1sp * Ndt80N - (kClb1d +  kClb1dp*ivna * Ama1N + kClb1dpp*ivna * (Ama1N + Ama1PN) + kClb1Cdc20d*ivna*APCpCdc20N) * Clb1N)
    dClb4_dt = 1.0*(kClb4s*vna + kClb4sp * Ndt80N - (kClb4d +  kClb4dp*ivna * Ama1N + kClb4dpp*ivna * (Ama1N + Ama1PN) + kClb4Cdc20d*ivna*APCpCdc20N) * Clb4N)
    dClb3_dt = 1.0*(kClb3s*vna - (kClb3d  + (kClb3dp*ivna * Ama1N + kClb3dpp*ivna * (Ama1N + Ama1PN)) + kClb3Cdc20d*ivna*APCpCdc20N) * Clb3N + AlphaClb3*(vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25) + kClb3sp*(1 - Rim4(t,Rim4_tau, Rim4_T))* Ndt80N) 
    dNdt80_dt = 1.0*(kNdt80s*vna + kNdt80sp*Ndt80N*vna/(Jfunc(Ndt80N) + Ndt80N) - kNdt80d * Ndt80N - kNdt80dp*ivna*Ama1N* Ndt80N) 
    dCdc20T_dt = 1.0*(kCdc20s*vna + kCdc20sp * Ndt80N - kCdc20d*Cdc20TN - kCdc20dp* APCpCdc20N)
    dAPCp_dt = kApcClb*Clb4N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) + kApcClb*Clb1N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) - kApcp* vna*APCpN/(JApcp*vna + APCpN) + kApcClb*Clb3N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N))
    dAPCpCdc20_dt = kApcCdc20a*APCpN*(Cdc20TN - APCpCdc20N)/(JApcCdc20a*vna + Cdc20TN - APCpCdc20N) - kApcCdc20d*vna*APCpCdc20N/(JApcCdc20d*vna + APCpCdc20N) 
    dCdc5A_dt = 1.0*((kCdc5a + kCdc5ap *ivna* Clb1N + kCdc5ap *ivna* Clb4N)*(Cdc5TN - Cdc5AN) - kCdc5i*Cdc5AN - (kCdc5d + kCdc5dp* ivna*Ama1N + kCdc5dpp* ivna*(Ama1N + Ama1PN) ) * Cdc5AN) + kCdc5app *ivna* Clb3N*(Cdc5TN - Cdc5AN)
    dCdc5T_dt = 1.0*(kCdc5s*vna + kCdc5sp * Ndt80N - (kCdc5d + kCdc5dp * ivna*Ama1N + kCdc5dpp * ivna*(Ama1N + Ama1PN)) * Cdc5TN)
    dAma1P_dt = 1.0*((kAma1i + kAma1ip*ivna*Clb1N + kAma1ip*ivna*Clb4N + kAma1ip*ivna*Clb3N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - kAma1dp*Ama1PN)
    dAma1_dt = 1.0*(kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - (kAma1i + kAma1ip*ivna*Clb1N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb4N * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb3N * Ama1N*vna/(JAma1*vna + Ama1N) + kAma1s*vna - kAma1dp*Ama1N + AlphakAma1s*(1*vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25))

    # Return the result as a NumPy array
    return np.array([dClb1_dt,  dClb4_dt, dClb3_dt, dNdt80_dt, dCdc20T_dt, dAPCp_dt, dAPCpCdc20_dt, dCdc5A_dt,  dCdc5T_dt, dAma1P_dt, dAma1_dt])

# Initial condition
Odes_0 = np.array([1.125* vna,0.12* vna,0.0,5 *vna,2*vna,0.0,0.1*vna,0.25 *vna,0.75*vna,0.0,0.0])
pn.extension()
Rim4_tau_slider = pn.widgets.FloatSlider(
    name="Rim4 τ", start=0, end=10, step=0.01, value=0.2
)
Rim4_T_slider = pn.widgets.FloatSlider(
    name="Rim4 T", start=1, end=200, step=1, value=20
)
t_max_slider = pn.widgets.FloatSlider(
    name="t max",start=1, end=300, step=1, value=140
)
@pn.depends(
    Rim4_tau_slider.param.value,
    Rim4_T_slider.param.value,
    t_max_slider.param.value,
   
)
def WildType_plot(
    Rim4_tau=0.2,
    Rim4_T=20,
    t_max=300,
):
    args = (
        Rim4_tau,
        Rim4_T
    )

      # Integrate ODES
    t = np.linspace(0, t_max, 400)
    Odes = scipy.integrate.odeint(Meiosis_ODE, Odes_0, t, args=args)
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N  = Odes.transpose()
  
    # Set up plot
    p = bokeh.plotting.figure(
        frame_width=425,
        frame_height=350,
        x_axis_label="Time (minutes)",
        y_axis_label="Protein Concentration (a.u.)",
        x_range=[0, t_max],
        
    )

      # Populate glyphs
    p.line(t, Clb1N/vna, line_width=2, color=colors[37], legend_label="Clb1")
    p.line(t, Clb4N/vna, line_width=2, color=colors[20], legend_label="Clb4")
    p.line(t, Clb3N/vna, line_width=2, color=colors[72], legend_label="Clb3")
    p.line(t, Ndt80N/vna, line_width=2, color=colors[3], legend_label="Ndt80N")
    #p.line(t, Cdc20TN, line_width=2, color=colors[4], legend_label="Cdc20TN")
    p.line(t, APCpN/vna, line_width=2, color=colors[87], legend_label="APCpN")
    p.line(t, APCpCdc20N/vna, line_width=2, color=colors[9], legend_label="APCpCdc20")
    p.line(t, Cdc5AN/vna, line_width=2, color=colors[70], legend_label="Cdc5A")
    #p.line(t, Cdc5TN, line_width=2, color=colors[8], legend_label="Cdc5TN")
    p.line(t, Ama1PN/vna, line_width=2, color=colors[14], legend_label="Ama1PN")
    p.line(t, Ama1N/vna , line_width=2, color=colors[10], legend_label="Ama1N")
    p.line(t, (Clb1N+Clb3N+Clb4N)/vna, line_width=3, color=colors[11], legend_label="Clb Total")
    p.line(t,0.47,line_width=3,color=colors[11],line_dash='4 4')

    

    # Place the legend
    p.legend.location = "top_right"
    p.xaxis.axis_label_text_font_size = "14pt"
    p.yaxis.axis_label_text_font_size = "14pt"
    p.yaxis.major_label_text_font_size = '12pt'
    p.xaxis.major_label_text_font_size = '11pt'
    
    return p
    
widgets = pn.Column(
    pn.Spacer(height=10),
    Rim4_tau_slider,
    Rim4_T_slider,
    t_max_slider,
    width=150,
)

left_column = pn.Column(
    pn.Row(pn.Spacer(width=20), WildType_plot,
))

# Final layout
pn.Row(left_column, pn.Spacer(width=20),widgets)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='c18d5397-3c0d-4fca-9c3e-be9421b73cd4'>
#   <div id="ca3eefe2-8460-4f74-9ab3-5e8820602fc5" data-root-id="c18d5397-3c0d-4fca-9c3e-be9421b73cd4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"8da6b244-0700-4577-b2fa-e0b9f934b966":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"c18d5397-3c0d-4fca-9c3e-be9421b73cd4"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"5539e935-8735-4904-81d6-b61e04472c4e","attributes":{"plot_id":"c18d5397-3c0d-4fca-9c3e-be9421b73cd4","comm_id":"f7444f668116436fbf70bc329cc24d61","client_comm_id":"3dd200fe78374686917acd9515c39a0c"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"8da6b244-0700-4577-b2fa-e0b9f934b966","roots":{"c18d5397-3c0d-4fca-9c3e-be9421b73cd4":"ca3eefe2-8460-4f74-9ab3-5e8820602fc5"},"root_ids":["c18d5397-3c0d-4fca-9c3e-be9421b73cd4"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Row
#     [0] Column
#         [0] Row
#             [0] Spacer(width=20)
#             [1] ParamFunction(function, _pane=Bokeh, defer_load=False)
#     [1] Spacer(width=20)
#     [2] Column(width=150)
#         [0] Spacer(height=10)
#         [1] FloatSlider(end=10, name='Rim4 τ', step=0.01, value=0.2)
#         [2] FloatSlider(end=200, name='Rim4 T', start=1, step=1, value=20)
#         [3] FloatSlider(end=300, name='t max', start=1, step=1, value=140)

# %%
#----Ama1 mutant----

def Ama1Mut_ODE(Odes, t, Rim4_tau, Rim4_T):
    
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N = Odes

    # Compute dOdes/dt
    dClb1_dt = 1.0*(kClb1s*vna + kClb1sp * Ndt80N - (kClb1d +  kClb1dp*ivna * Ama1N + kClb1dpp*ivna * (Ama1N + Ama1PN) + kClb1Cdc20d*ivna*APCpCdc20N) * Clb1N)
    dClb4_dt = 1.0*(kClb4s*vna + kClb4sp * Ndt80N - (kClb4d +  kClb4dp*ivna * Ama1N + kClb4dpp*ivna * (Ama1N + Ama1PN) + kClb4Cdc20d*ivna*APCpCdc20N) * Clb4N)
    dClb3_dt = 1.0*(kClb3s*vna - (kClb3d  + (kClb3dp*ivna * Ama1N + kClb3dpp*ivna * (Ama1N + Ama1PN)) + kClb3Cdc20d*ivna*APCpCdc20N) * Clb3N + AlphaClb3*(vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25) + kClb3sp*(1 - Rim4(t,Rim4_tau, Rim4_T))* Ndt80N) 
    dNdt80_dt = 1.0*(kNdt80s*vna + kNdt80sp*Ndt80N*vna/(Jfunc(Ndt80N) + Ndt80N) - kNdt80d * Ndt80N - kNdt80dp*ivna*Ama1N* Ndt80N) 
    dCdc20T_dt = 1.0*(kCdc20s*vna + kCdc20sp * Ndt80N - kCdc20d*Cdc20TN - kCdc20dp* APCpCdc20N)
    dAPCp_dt = kApcClb*Clb4N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) + kApcClb*Clb1N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) - kApcp* vna*APCpN/(JApcp*vna + APCpN) + kApcClb*Clb3N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N))
    dAPCpCdc20_dt = kApcCdc20a*APCpN*(Cdc20TN - APCpCdc20N)/(JApcCdc20a*vna + Cdc20TN - APCpCdc20N) - kApcCdc20d*vna*APCpCdc20N/(JApcCdc20d*vna + APCpCdc20N) 
    dCdc5A_dt = 1.0*((kCdc5a + kCdc5ap *ivna* Clb1N + kCdc5ap *ivna* Clb4N)*(Cdc5TN - Cdc5AN) - kCdc5i*Cdc5AN - (kCdc5d + kCdc5dp* ivna*Ama1N + kCdc5dpp* ivna*(Ama1N + Ama1PN) ) * Cdc5AN) + kCdc5app *ivna* Clb3N*(Cdc5TN - Cdc5AN)
    dCdc5T_dt = 1.0*(kCdc5s*vna + kCdc5sp * Ndt80N - (kCdc5d + kCdc5dp * ivna*Ama1N + kCdc5dpp * ivna*(Ama1N + Ama1PN)) * Cdc5TN)
    dAma1P_dt = 0.0*((kAma1i + kAma1ip*ivna*Clb1N + kAma1ip*ivna*Clb4N + kAma1ip*ivna*Clb3N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - kAma1dp*Ama1PN)
    dAma1_dt = 0.0*(kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - (kAma1i + kAma1ip*ivna*Clb1N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb4N * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb3N * Ama1N*vna/(JAma1*vna + Ama1N) + kAma1s*vna - kAma1dp*Ama1N + AlphakAma1s*(1*vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25))

    # Return the result as a NumPy array
    return np.array([dClb1_dt,  dClb4_dt, dClb3_dt, dNdt80_dt, dCdc20T_dt, dAPCp_dt, dAPCpCdc20_dt, dCdc5A_dt,  dCdc5T_dt, dAma1P_dt, dAma1_dt])

# Initial condition
Odes_0 = np.array([1.125* vna,0.12* vna,0.0,5 *vna,2*vna,0.0,0.1*vna,0.25 *vna,0.75*vna,0.0,0.0])

#Sliders

pn.extension()
Rim4_tau_slider = pn.widgets.FloatSlider(
    name="Rim4 τ", start=0, end=10, step=0.01, value=0.2
)
Rim4_T_slider = pn.widgets.FloatSlider(
    name="Rim4 T", start=1, end=100, step=1, value=20
)
t_max_slider = pn.widgets.FloatSlider(
    name="t max",start=1, end=300, step=1, value=140
)
@pn.depends(
    Rim4_tau_slider.param.value,
    Rim4_T_slider.param.value,
    t_max_slider.param.value,
   
)

def Ama1Mut_plot(
    Rim4_tau=0.2,
    Rim4_T=20,
    t_max=200,
):
    args = (
        Rim4_tau,
        Rim4_T
    )

      # Integrate ODES
    t = np.linspace(0, t_max, 400)
    Odes = scipy.integrate.odeint(Ama1Mut_ODE, Odes_0, t, args=args)
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N  = Odes.transpose()
  
    # Set up plot
    p = bokeh.plotting.figure(
        frame_width=425,
        frame_height=350,
        x_axis_label="Time (minutes)",
        y_axis_label="Protein Concentration (a.u.)",
        x_range=[0, t_max],
    )

      # Populate glyphs
    p.line(t, Clb1N/vna, line_width=2, color=colors[37], legend_label="Clb1")
    p.line(t, Clb4N/vna, line_width=2, color=colors[20], legend_label="Clb4")
    p.line(t, Clb3N/vna, line_width=2, color=colors[72], legend_label="Clb3")
    #p.line(t, Ndt80N/vna, line_width=2, color=colors[3], legend_label="Ndt80N")
    #p.line(t, Cdc20TN, line_width=2, color=colors[4], legend_label="Cdc20TN")
    #p.line(t, APCpN, line_width=2, color=colors[5], legend_label="APCpN")
    p.line(t, APCpCdc20N/vna, line_width=2, color=colors[9], legend_label="APCpCdc20")
    p.line(t, Cdc5AN/vna, line_width=2, color=colors[70], legend_label="Cdc5A")
    #p.line(t, Cdc5TN, line_width=2, color=colors[8], legend_label="Cdc5TN")
    #p.line(t, Ama1PN, line_width=2, color=colors[9], legend_label="Ama1PN")
    #p.line(t, Ama1N , line_width=2, color=colors[10], legend_label="Ama1N")
    p.line(t, (Clb1N+Clb3N+Clb4N)/vna, line_width=2, color=colors[11], legend_label="Clb Total")
    p.line(t,0.47,line_width=3,color=colors[11],line_dash='4 4')

    

     # Place the legend
    p.legend.location = "top_right"
    p.xaxis.axis_label_text_font_size = "14pt"
    p.yaxis.axis_label_text_font_size = "14pt"
    p.yaxis.major_label_text_font_size = '12pt'
    p.xaxis.major_label_text_font_size = '11pt'
    


    return p
    
widgets = pn.Column(
    pn.Spacer(height=10),
    Rim4_tau_slider,
    Rim4_T_slider,
    t_max_slider,
    width=150,
)
left_column = pn.Column(
    pn.Row(pn.Spacer(width=10)), Ama1Mut_plot,
)

# Final layout
pn.Row(left_column, pn.Spacer(width=20),widgets)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a5e136f7-615e-4928-b6ef-0a5204a7e140'>
#   <div id="a0db588c-0580-4bbf-b35d-91f2f94b7299" data-root-id="a5e136f7-615e-4928-b6ef-0a5204a7e140" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"539f22c8-9e07-4da9-8973-fccf75491e25":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"a5e136f7-615e-4928-b6ef-0a5204a7e140"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"88f4c38c-18d4-4cc5-b5d4-025a4edfb105","attributes":{"plot_id":"a5e136f7-615e-4928-b6ef-0a5204a7e140","comm_id":"b0a481af524b4c8b90312318f8d8b643","client_comm_id":"4da84147fee244e39fc3c2bc0ea41880"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"539f22c8-9e07-4da9-8973-fccf75491e25","roots":{"a5e136f7-615e-4928-b6ef-0a5204a7e140":"a0db588c-0580-4bbf-b35d-91f2f94b7299"},"root_ids":["a5e136f7-615e-4928-b6ef-0a5204a7e140"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Row
#     [0] Column
#         [0] Row
#             [0] Spacer(width=10)
#         [1] ParamFunction(function, _pane=Bokeh, defer_load=False)
#     [1] Spacer(width=20)
#     [2] Column(width=150)
#         [0] Spacer(height=10)
#         [1] FloatSlider(end=10, name='Rim4 τ', step=0.01, value=0.2)
#         [2] FloatSlider(end=100, name='Rim4 T', start=1, step=1, value=20)
#         [3] FloatSlider(end=300, name='t max', start=1, step=1, value=140)

# %%
#----Clb1 mutant----

def Clb1Mut_ODE(Odes, t, Rim4_tau, Rim4_T):
    
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N = Odes

    # Compute dOdes/dt
    dClb1_dt = 0.0*(kClb1s*vna + kClb1sp * Ndt80N - (kClb1d +  kClb1dp*ivna * Ama1N + kClb1dpp*ivna * (Ama1N + Ama1PN) + kClb1Cdc20d*ivna*APCpCdc20N) * Clb1N)
    dClb4_dt = 1.0*(kClb4s*vna + kClb4sp * Ndt80N - (kClb4d +  kClb4dp*ivna * Ama1N + kClb4dpp*ivna * (Ama1N + Ama1PN) + kClb4Cdc20d*ivna*APCpCdc20N) * Clb4N)
    dClb3_dt = 1.0*(kClb3s*vna - (kClb3d  + (kClb3dp*ivna * Ama1N + kClb3dpp*ivna * (Ama1N + Ama1PN)) + kClb3Cdc20d*ivna*APCpCdc20N) * Clb3N + AlphaClb3*(vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25) + kClb3sp*(1 - Rim4(t,Rim4_tau, Rim4_T))* Ndt80N) 
    dNdt80_dt = 1.0*(kNdt80s*vna + kNdt80sp*Ndt80N*vna/(Jfunc(Ndt80N) + Ndt80N) - kNdt80d * Ndt80N - kNdt80dp*ivna*Ama1N* Ndt80N) 
    dCdc20T_dt = 1.0*(kCdc20s*vna + kCdc20sp * Ndt80N - kCdc20d*Cdc20TN - kCdc20dp* APCpCdc20N)
    dAPCp_dt = kApcClb*Clb4N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) + kApcClb*Clb1N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) - kApcp* vna*APCpN/(JApcp*vna + APCpN) + kApcClb*Clb3N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N))
    dAPCpCdc20_dt = kApcCdc20a*APCpN*(Cdc20TN - APCpCdc20N)/(JApcCdc20a*vna + Cdc20TN - APCpCdc20N) - kApcCdc20d*vna*APCpCdc20N/(JApcCdc20d*vna + APCpCdc20N) 
    dCdc5A_dt = 1.0*((kCdc5a + kCdc5ap *ivna* Clb1N + kCdc5ap *ivna* Clb4N)*(Cdc5TN - Cdc5AN) - kCdc5i*Cdc5AN - (kCdc5d + kCdc5dp* ivna*Ama1N + kCdc5dpp* ivna*(Ama1N + Ama1PN) ) * Cdc5AN) + kCdc5app *ivna* Clb3N*(Cdc5TN - Cdc5AN)
    dCdc5T_dt = 1.0*(kCdc5s*vna + kCdc5sp * Ndt80N - (kCdc5d + kCdc5dp * ivna*Ama1N + kCdc5dpp * ivna*(Ama1N + Ama1PN)) * Cdc5TN)
    dAma1P_dt = 1.0*((kAma1i + kAma1ip*ivna*Clb1N + kAma1ip*ivna*Clb4N + kAma1ip*ivna*Clb3N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - kAma1dp*Ama1PN)
    dAma1_dt = 1.0*(kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - (kAma1i + kAma1ip*ivna*Clb1N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb4N * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb3N * Ama1N*vna/(JAma1*vna + Ama1N) + kAma1s*vna - kAma1dp*Ama1N + AlphakAma1s*(1*vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25))

    # Return the result as a NumPy array
    return np.array([dClb1_dt,  dClb4_dt, dClb3_dt, dNdt80_dt, dCdc20T_dt, dAPCp_dt, dAPCpCdc20_dt, dCdc5A_dt,  dCdc5T_dt, dAma1P_dt, dAma1_dt])

# Initial condition
Odes_0 = np.array([0,0.12* vna,0.0,5 *vna,2*vna,0.0,0.1*vna,0.25 *vna,0.75*vna,0.0,0.0])

#Sliders

pn.extension()
Rim4_tau_slider = pn.widgets.FloatSlider(
    name="Rim4 τ", start=0, end=10, step=0.01, value=0.2
)
Rim4_T_slider = pn.widgets.FloatSlider(
    name="Rim4 T", start=1, end=100, step=1, value=20
)
t_max_slider = pn.widgets.FloatSlider(
    name="t max",start=1, end=300, step=1, value=140
)
@pn.depends(
    Rim4_tau_slider.param.value,
    Rim4_T_slider.param.value,
    t_max_slider.param.value,
   
)

def Clb1Mut_plot(
    Rim4_tau=0.2,
    Rim4_T=20,
    t_max=140,
):
    args = (
        Rim4_tau,
        Rim4_T
    )

      # Integrate ODES
    t = np.linspace(0, t_max, 400)
    Odes = scipy.integrate.odeint(Clb1Mut_ODE, Odes_0, t, args=args)
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N  = Odes.transpose()
  
    # Set up plot
    p = bokeh.plotting.figure(
        frame_width=425,
        frame_height=350,
        x_axis_label="Time (minutes)",
        y_axis_label="Protein Concentration (a.u.)",
        x_range=[0, t_max],
    )

      # Populate glyphs
    #p.line(t, Clb1N/vna, line_width=2, color=colors[37], legend_label="Clb1")
    p.line(t, Clb4N/vna, line_width=2, color=colors[20], legend_label="Clb4")
    p.line(t, Clb3N/vna, line_width=2, color=colors[72], legend_label="Clb3")
    #p.line(t, Ndt80N, line_width=2, color=colors[3], legend_label="Ndt80N")
    #p.line(t, Cdc20TN, line_width=2, color=colors[4], legend_label="Cdc20TN")
    #p.line(t, APCpN, line_width=2, color=colors[5], legend_label="APCpN")
    p.line(t, APCpCdc20N/vna, line_width=2, color=colors[9], legend_label="APCpCdc20")
    p.line(t, Cdc5AN/vna, line_width=2, color=colors[70], legend_label="Cdc5A")
    #p.line(t, Cdc5TN, line_width=2, color=colors[8], legend_label="Cdc5TN")
    #p.line(t, Ama1PN, line_width=2, color=colors[9], legend_label="Ama1PN")
    #p.line(t, Ama1N , line_width=2, color=colors[10], legend_label="Ama1N")
    p.line(t, (Clb1N+Clb3N+Clb4N)/vna, line_width=2, color=colors[11], legend_label="Clb Total")
    p.line(t,0.47,line_width=3,color=colors[11],line_dash='4 4')
    

    

     # Place the legend
    p.legend.location = "top_right"
    p.xaxis.axis_label_text_font_size = "14pt"
    p.yaxis.axis_label_text_font_size = "14pt"
    p.yaxis.major_label_text_font_size = '12pt'
    p.xaxis.major_label_text_font_size = '11pt'


    return p
    
widgets = pn.Column(
    pn.Spacer(height=10),
    Rim4_tau_slider,
    Rim4_T_slider,
    t_max_slider,
    width=150,
)

left_column = pn.Column(
    pn.Row(pn.Spacer(width=10)), Clb1Mut_plot,
)

# Final layout
pn.Row(left_column, pn.Spacer(width=20),widgets)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='ce1ccc4c-dd3c-49fc-b63f-cdfac7469f83'>
#   <div id="a6605356-f620-4c49-bea6-effc4e7f83fe" data-root-id="ce1ccc4c-dd3c-49fc-b63f-cdfac7469f83" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"c14a1214-62f3-468e-a66a-37c3ff3f2166":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"ce1ccc4c-dd3c-49fc-b63f-cdfac7469f83"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"d2170f8a-4ac2-472a-991c-2b0f3d840d98","attributes":{"plot_id":"ce1ccc4c-dd3c-49fc-b63f-cdfac7469f83","comm_id":"3a836f039dad4534983a83b2dd77edd4","client_comm_id":"3944cab9d7de494ebad1275ed99ef10f"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"c14a1214-62f3-468e-a66a-37c3ff3f2166","roots":{"ce1ccc4c-dd3c-49fc-b63f-cdfac7469f83":"a6605356-f620-4c49-bea6-effc4e7f83fe"},"root_ids":["ce1ccc4c-dd3c-49fc-b63f-cdfac7469f83"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Row
#     [0] Column
#         [0] Row
#             [0] Spacer(width=10)
#         [1] ParamFunction(function, _pane=Bokeh, defer_load=False)
#     [1] Spacer(width=20)
#     [2] Column(width=150)
#         [0] Spacer(height=10)
#         [1] FloatSlider(end=10, name='Rim4 τ', step=0.01, value=0.2)
#         [2] FloatSlider(end=100, name='Rim4 T', start=1, step=1, value=20)
#         [3] FloatSlider(end=300, name='t max', start=1, step=1, value=140)

# %%
#----Clb3 mutant----

def Clb3Mut_ODE(Odes, t, Rim4_tau, Rim4_T):
    
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N = Odes

    # Compute dOdes/dt
    dClb1_dt = 1.0*(kClb1s*vna + kClb1sp * Ndt80N - (kClb1d +  kClb1dp*ivna * Ama1N + kClb1dpp*ivna * (Ama1N + Ama1PN) + kClb1Cdc20d*ivna*APCpCdc20N) * Clb1N)
    dClb4_dt = 1.0*(kClb4s*vna + kClb4sp * Ndt80N - (kClb4d +  kClb4dp*ivna * Ama1N + kClb4dpp*ivna * (Ama1N + Ama1PN) + kClb4Cdc20d*ivna*APCpCdc20N) * Clb4N)
    dClb3_dt = 0.0*(kClb3s*vna - (kClb3d  + (kClb3dp*ivna * Ama1N + kClb3dpp*ivna * (Ama1N + Ama1PN)) + kClb3Cdc20d*ivna*APCpCdc20N) * Clb3N + AlphaClb3*(vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25) + kClb3sp*(1 - Rim4(t,Rim4_tau, Rim4_T))* Ndt80N) 
    dNdt80_dt = 1.0*(kNdt80s*vna + kNdt80sp*Ndt80N*vna/(Jfunc(Ndt80N) + Ndt80N) - kNdt80d * Ndt80N - kNdt80dp*ivna*Ama1N* Ndt80N) 
    dCdc20T_dt = 1.0*(kCdc20s*vna + kCdc20sp * Ndt80N - kCdc20d*Cdc20TN - kCdc20dp* APCpCdc20N)
    dAPCp_dt = kApcClb*Clb4N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) + kApcClb*Clb1N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) - kApcp* vna*APCpN/(JApcp*vna + APCpN) + kApcClb*Clb3N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N))
    dAPCpCdc20_dt = kApcCdc20a*APCpN*(Cdc20TN - APCpCdc20N)/(JApcCdc20a*vna + Cdc20TN - APCpCdc20N) - kApcCdc20d*vna*APCpCdc20N/(JApcCdc20d*vna + APCpCdc20N) 
    dCdc5A_dt = 1.0*((kCdc5a + kCdc5ap *ivna* Clb1N + kCdc5ap *ivna* Clb4N)*(Cdc5TN - Cdc5AN) - kCdc5i*Cdc5AN - (kCdc5d + kCdc5dp* ivna*Ama1N + kCdc5dpp* ivna*(Ama1N + Ama1PN) ) * Cdc5AN) + kCdc5app *ivna* Clb3N*(Cdc5TN - Cdc5AN)
    dCdc5T_dt = 1.0*(kCdc5s*vna + kCdc5sp * Ndt80N - (kCdc5d + kCdc5dp * ivna*Ama1N + kCdc5dpp * ivna*(Ama1N + Ama1PN)) * Cdc5TN)
    dAma1P_dt = 1.0*((kAma1i + kAma1ip*ivna*Clb1N + kAma1ip*ivna*Clb4N + kAma1ip*ivna*Clb3N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - kAma1dp*Ama1PN)
    dAma1_dt = 1.0*(kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - (kAma1i + kAma1ip*ivna*Clb1N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb4N * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb3N * Ama1N*vna/(JAma1*vna + Ama1N) + kAma1s*vna - kAma1dp*Ama1N + AlphakAma1s*(1*vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25))

    # Return the result as a NumPy array
    return np.array([dClb1_dt,  dClb4_dt, dClb3_dt, dNdt80_dt, dCdc20T_dt, dAPCp_dt, dAPCpCdc20_dt, dCdc5A_dt,  dCdc5T_dt, dAma1P_dt, dAma1_dt])

# Initial condition
Odes_0 = np.array([1.125* vna,0.12* vna,0.0,5 *vna,2*vna,0.0,0.1*vna,0.25 *vna,0.75*vna,0.0,0.0])

#Sliders

pn.extension()
Rim4_tau_slider = pn.widgets.FloatSlider(
    name="Rim4 τ", start=0, end=10, step=0.01, value=0.2
)
Rim4_T_slider = pn.widgets.FloatSlider(
    name="Rim4 T", start=1, end=100, step=1, value=20
)
t_max_slider = pn.widgets.FloatSlider(
    name="t max",start=1, end=300, step=1, value=140
)
@pn.depends(
    Rim4_tau_slider.param.value,
    Rim4_T_slider.param.value,
    t_max_slider.param.value,
   
)
def Clb3Mut_plot(
    Rim4_tau=0.2,
    Rim4_T=20,
    t_max=200,
):
    args = (
        Rim4_tau,
        Rim4_T
    )

      # Integrate ODES
    t = np.linspace(0, t_max, 400)
    Odes = scipy.integrate.odeint(Clb3Mut_ODE, Odes_0, t, args=args)
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N  = Odes.transpose()
  
    # Set up plot
    p = bokeh.plotting.figure(
        frame_width=425,
        frame_height=350,
        x_axis_label="Time (minutes)",
        y_axis_label="Protein Concentration (a.u.)",
        x_range=[0, t_max],
    )

      # Populate glyphs
    p.line(t, Clb1N/vna, line_width=2, color=colors[37], legend_label="Clb1")
    p.line(t, Clb4N/vna, line_width=2, color=colors[20], legend_label="Clb4")
    #p.line(t, Clb3N/vna, line_width=2, color=colors[72], legend_label="Clb3")
    #p.line(t, Ndt80N, line_width=2, color=colors[3], legend_label="Ndt80N")
    #p.line(t, Cdc20TN, line_width=2, color=colors[4], legend_label="Cdc20TN")
    #p.line(t, APCpN, line_width=2, color=colors[5], legend_label="APCpN")
    p.line(t, APCpCdc20N/vna, line_width=2, color=colors[9], legend_label="APCpCdc20")
    p.line(t, Cdc5AN/vna, line_width=2, color=colors[70], legend_label="Cdc5A")
    #p.line(t, Cdc5TN, line_width=2, color=colors[8], legend_label="Cdc5TN")
    #p.line(t, Ama1PN, line_width=2, color=colors[9], legend_label="Ama1PN")
    #p.line(t, Ama1N , line_width=2, color=colors[10], legend_label="Ama1N")
    p.line(t, (Clb1N+Clb3N+Clb4N)/vna, line_width=2, color=colors[11], legend_label="Clb Total")
    p.line(t,0.47,line_width=3,color=colors[11],line_dash='4 4')

    

     # Place the legend
    p.legend.location = "top_right"
    p.xaxis.axis_label_text_font_size = "14pt"
    p.yaxis.axis_label_text_font_size = "14pt"
    p.yaxis.major_label_text_font_size = '12pt'
    p.xaxis.major_label_text_font_size = '11pt'


    return p
    
widgets = pn.Column(
    pn.Spacer(height=10),
    Rim4_tau_slider,
    Rim4_T_slider,
    t_max_slider,
    width=150,
)

left_column = pn.Column(
    pn.Row(pn.Spacer(width=10)), Clb3Mut_plot,
)

# Final layout
pn.Row(left_column, pn.Spacer(width=20),widgets)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a285ad2a-9471-42a8-997f-be12fc44cf2d'>
#   <div id="f37b0dbd-e087-4cc3-98cb-c7b796604fb5" data-root-id="a285ad2a-9471-42a8-997f-be12fc44cf2d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"32175aeb-129c-4552-8385-694ee521c4ce":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"a285ad2a-9471-42a8-997f-be12fc44cf2d"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"985a9428-1b4d-4dd3-8779-3e456193e230","attributes":{"plot_id":"a285ad2a-9471-42a8-997f-be12fc44cf2d","comm_id":"077d92bb4dc74d70a0ffb071d8ff3ae9","client_comm_id":"1f2f116b2a7a4231922a7a9b52a2c6cc"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"32175aeb-129c-4552-8385-694ee521c4ce","roots":{"a285ad2a-9471-42a8-997f-be12fc44cf2d":"f37b0dbd-e087-4cc3-98cb-c7b796604fb5"},"root_ids":["a285ad2a-9471-42a8-997f-be12fc44cf2d"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Row
#     [0] Column
#         [0] Row
#             [0] Spacer(width=10)
#         [1] ParamFunction(function, _pane=Bokeh, defer_load=False)
#     [1] Spacer(width=20)
#     [2] Column(width=150)
#         [0] Spacer(height=10)
#         [1] FloatSlider(end=10, name='Rim4 τ', step=0.01, value=0.2)
#         [2] FloatSlider(end=100, name='Rim4 T', start=1, step=1, value=20)
#         [3] FloatSlider(end=300, name='t max', start=1, step=1, value=140)

# %%
#----Clb4 mutant----

def Clb4Mut_ODE(Odes, t, Rim4_tau, Rim4_T):
    
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N = Odes

   # Compute dOdes/dt
    dClb1_dt = 1.0*(kClb1s*vna + kClb1sp * Ndt80N - (kClb1d +  kClb1dp*ivna * Ama1N + kClb1dpp*ivna * (Ama1N + Ama1PN) + kClb1Cdc20d*ivna*APCpCdc20N) * Clb1N)
    dClb4_dt = 0.0*(kClb4s*vna + kClb4sp * Ndt80N - (kClb4d +  kClb4dp*ivna * Ama1N + kClb4dpp*ivna * (Ama1N + Ama1PN) + kClb4Cdc20d*ivna*APCpCdc20N) * Clb4N)
    dClb3_dt = 1.0*(kClb3s*vna - (kClb3d  + (kClb3dp*ivna * Ama1N + kClb3dpp*ivna * (Ama1N + Ama1PN)) + kClb3Cdc20d*ivna*APCpCdc20N) * Clb3N + AlphaClb3*(vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25) + kClb3sp*(1 - Rim4(t,Rim4_tau, Rim4_T))* Ndt80N) 
    dNdt80_dt = 1.0*(kNdt80s*vna + kNdt80sp*Ndt80N*vna/(Jfunc(Ndt80N) + Ndt80N) - kNdt80d * Ndt80N - kNdt80dp*ivna*Ama1N* Ndt80N) 
    dCdc20T_dt = 1.0*(kCdc20s*vna + kCdc20sp * Ndt80N - kCdc20d*Cdc20TN - kCdc20dp* APCpCdc20N)
    dAPCp_dt = kApcClb*Clb4N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) + kApcClb*Clb1N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) - kApcp* vna*APCpN/(JApcp*vna + APCpN) + kApcClb*Clb3N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N))
    dAPCpCdc20_dt = kApcCdc20a*APCpN*(Cdc20TN - APCpCdc20N)/(JApcCdc20a*vna + Cdc20TN - APCpCdc20N) - kApcCdc20d*vna*APCpCdc20N/(JApcCdc20d*vna + APCpCdc20N) 
    dCdc5A_dt = 1.0*((kCdc5a + kCdc5ap *ivna* Clb1N + kCdc5ap *ivna* Clb4N)*(Cdc5TN - Cdc5AN) - kCdc5i*Cdc5AN - (kCdc5d + kCdc5dp* ivna*Ama1N + kCdc5dpp* ivna*(Ama1N + Ama1PN) ) * Cdc5AN) + kCdc5app *ivna* Clb3N*(Cdc5TN - Cdc5AN)
    dCdc5T_dt = 1.0*(kCdc5s*vna + kCdc5sp * Ndt80N - (kCdc5d + kCdc5dp * ivna*Ama1N + kCdc5dpp * ivna*(Ama1N + Ama1PN)) * Cdc5TN)
    dAma1P_dt = 1.0*((kAma1i + kAma1ip*ivna*Clb1N + kAma1ip*ivna*Clb4N + kAma1ip*ivna*Clb3N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - kAma1dp*Ama1PN)
    dAma1_dt = 1.0*(kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - (kAma1i + kAma1ip*ivna*Clb1N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb4N * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb3N * Ama1N*vna/(JAma1*vna + Ama1N) + kAma1s*vna - kAma1dp*Ama1N + AlphakAma1s*(1*vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25))
    # Return the result as a NumPy array
    return np.array([dClb1_dt,  dClb4_dt, dClb3_dt, dNdt80_dt, dCdc20T_dt, dAPCp_dt, dAPCpCdc20_dt, dCdc5A_dt,  dCdc5T_dt, dAma1P_dt, dAma1_dt])


# Initial condition
Odes_0 = np.array([1.125* vna,0.0,0.0,5 *vna,2*vna,0.0,0.1*vna,0.25 *vna,0.75*vna,0.0,0.0])
#Sliders

pn.extension()
Rim4_tau_slider = pn.widgets.FloatSlider(
    name="Rim4 τ", start=0, end=10, step=0.01, value=0.2
)
Rim4_T_slider = pn.widgets.FloatSlider(
    name="Rim4 T", start=1, end=100, step=1, value=20
)
t_max_slider = pn.widgets.FloatSlider(
    name="t max",start=1, end=300, step=1, value=140
)
@pn.depends(
    Rim4_tau_slider.param.value,
    Rim4_T_slider.param.value,
    t_max_slider.param.value,
   
)
def Clb4Mut_plot(
    Rim4_tau=0.2,
    Rim4_T=20,
    t_max=200,
):
    args = (
        Rim4_tau,
        Rim4_T
    )

      # Integrate ODES
    t = np.linspace(0, t_max, 400)
    Odes = scipy.integrate.odeint(Clb4Mut_ODE, Odes_0, t, args=args)
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N  = Odes.transpose()
  
    # Set up plot
    p = bokeh.plotting.figure(
        frame_width=425,
        frame_height=350,
        x_axis_label="Time (minutes)",
        y_axis_label="Protein Concentration (a.u.)",
        x_range=[0, t_max],
    )

      # Populate glyphs
    p.line(t, Clb1N/vna, line_width=2, color=colors[37], legend_label="Clb1")
    #p.line(t, Clb4N/vna, line_width=2, color=colors[20], legend_label="Clb4")
    p.line(t, Clb3N/vna, line_width=2, color=colors[72], legend_label="Clb3")
    #p.line(t, Ndt80N, line_width=2, color=colors[3], legend_label="Ndt80N")
    #p.line(t, Cdc20TN, line_width=2, color=colors[4], legend_label="Cdc20TN")
    #p.line(t, APCpN, line_width=2, color=colors[5], legend_label="APCpN")
    p.line(t, APCpCdc20N/vna, line_width=2, color=colors[9], legend_label="APCpCdc20")
    p.line(t, Cdc5AN/vna, line_width=2, color=colors[70], legend_label="Cdc5A")
    #p.line(t, Cdc5TN, line_width=2, color=colors[8], legend_label="Cdc5TN")
    #p.line(t, Ama1PN, line_width=2, color=colors[9], legend_label="Ama1PN")
    #p.line(t, Ama1N , line_width=2, color=colors[10], legend_label="Ama1N")
    p.line(t, (Clb1N+Clb3N+Clb4N)/vna, line_width=2, color=colors[11], legend_label="Clb Total")
    p.line(t,0.47,line_width=3,color=colors[11],line_dash='4 4')

    

     # Place the legend
    p.legend.location = "top_right"
    p.xaxis.axis_label_text_font_size = "14pt"
    p.yaxis.axis_label_text_font_size = "14pt"
    p.yaxis.major_label_text_font_size = '12pt'
    p.xaxis.major_label_text_font_size = '11pt'


    return p
    
widgets = pn.Column(
    pn.Spacer(height=10),
    Rim4_tau_slider,
    Rim4_T_slider,
    t_max_slider,
    width=150,
)

left_column = pn.Column(
    pn.Row(pn.Spacer(width=10)), Clb4Mut_plot,
)

# Final layout
pn.Row(left_column, pn.Spacer(width=20),widgets)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='b214066c-ba3c-4cbc-b58e-e2e710659ef0'>
#   <div id="ae527934-35fc-4a0e-a612-2a9e338b2088" data-root-id="b214066c-ba3c-4cbc-b58e-e2e710659ef0" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"99748619-aefc-4fa9-864d-858ab7e7c9b8":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"b214066c-ba3c-4cbc-b58e-e2e710659ef0"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"ee6ccefe-aaf8-41b2-8a56-239803d502dc","attributes":{"plot_id":"b214066c-ba3c-4cbc-b58e-e2e710659ef0","comm_id":"b29cef3f964047d9934faf0eff922f8d","client_comm_id":"d037b81fe1a6468c8783df0c16b6d88c"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"99748619-aefc-4fa9-864d-858ab7e7c9b8","roots":{"b214066c-ba3c-4cbc-b58e-e2e710659ef0":"ae527934-35fc-4a0e-a612-2a9e338b2088"},"root_ids":["b214066c-ba3c-4cbc-b58e-e2e710659ef0"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Row
#     [0] Column
#         [0] Row
#             [0] Spacer(width=10)
#         [1] ParamFunction(function, _pane=Bokeh, defer_load=False)
#     [1] Spacer(width=20)
#     [2] Column(width=150)
#         [0] Spacer(height=10)
#         [1] FloatSlider(end=10, name='Rim4 τ', step=0.01, value=0.2)
#         [2] FloatSlider(end=100, name='Rim4 T', start=1, step=1, value=20)
#         [3] FloatSlider(end=300, name='t max', start=1, step=1, value=140)

# %%
#----Clb4 + Clb1 mutant----

def Clb41Mut_ODE(Odes, t, Rim4_tau, Rim4_T):
    
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N = Odes

    # Compute dOdes/dt
    dClb1_dt = 0.0*(kClb1s*vna + kClb1sp * Ndt80N - (kClb1d +  kClb1dp*ivna * Ama1N + kClb1dpp*ivna * (Ama1N + Ama1PN) + kClb1Cdc20d*ivna*APCpCdc20N) * Clb1N)
    dClb4_dt = 0.0*(kClb4s*vna + kClb4sp * Ndt80N - (kClb4d +  kClb4dp*ivna * Ama1N + kClb4dpp*ivna * (Ama1N + Ama1PN) + kClb4Cdc20d*ivna*APCpCdc20N) * Clb4N)
    dClb3_dt = 1.0*(kClb3s*vna - (kClb3d  + (kClb3dp*ivna * Ama1N + kClb3dpp*ivna * (Ama1N + Ama1PN)) + kClb3Cdc20d*ivna*APCpCdc20N) * Clb3N + AlphaClb3*(vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25) + kClb3sp*(1 - Rim4(t,Rim4_tau, Rim4_T))* Ndt80N) 
    dNdt80_dt = 1.0*(kNdt80s*vna + kNdt80sp*Ndt80N*vna/(Jfunc(Ndt80N) + Ndt80N) - kNdt80d * Ndt80N - kNdt80dp*ivna*Ama1N* Ndt80N) 
    dCdc20T_dt = 1.0*(kCdc20s*vna + kCdc20sp * Ndt80N - kCdc20d*Cdc20TN - kCdc20dp* APCpCdc20N)
    dAPCp_dt = kApcClb*Clb4N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) + kApcClb*Clb1N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) - kApcp* vna*APCpN/(JApcp*vna + APCpN) + kApcClb*Clb3N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N))
    dAPCpCdc20_dt = kApcCdc20a*APCpN*(Cdc20TN - APCpCdc20N)/(JApcCdc20a*vna + Cdc20TN - APCpCdc20N) - kApcCdc20d*vna*APCpCdc20N/(JApcCdc20d*vna + APCpCdc20N) 
    dCdc5A_dt = 1.0*((kCdc5a + kCdc5ap *ivna* Clb1N + kCdc5ap *ivna* Clb4N)*(Cdc5TN - Cdc5AN) - kCdc5i*Cdc5AN - (kCdc5d + kCdc5dp* ivna*Ama1N + kCdc5dpp* ivna*(Ama1N + Ama1PN) ) * Cdc5AN) + kCdc5app *ivna* Clb3N*(Cdc5TN - Cdc5AN)
    dCdc5T_dt = 1.0*(kCdc5s*vna + kCdc5sp * Ndt80N - (kCdc5d + kCdc5dp * ivna*Ama1N + kCdc5dpp * ivna*(Ama1N + Ama1PN)) * Cdc5TN)
    dAma1P_dt = 1.0*((kAma1i + kAma1ip*ivna*Clb1N + kAma1ip*ivna*Clb4N + kAma1ip*ivna*Clb3N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - kAma1dp*Ama1PN)
    dAma1_dt = 1.0*(kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - (kAma1i + kAma1ip*ivna*Clb1N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb4N * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb3N * Ama1N*vna/(JAma1*vna + Ama1N) + kAma1s*vna - kAma1dp*Ama1N + AlphakAma1s*(1*vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25))
    # Return the result as a NumPy array
    return np.array([dClb1_dt,  dClb4_dt, dClb3_dt, dNdt80_dt, dCdc20T_dt, dAPCp_dt, dAPCpCdc20_dt, dCdc5A_dt,  dCdc5T_dt, dAma1P_dt, dAma1_dt])


# Initial condition
Odes_0 = np.array([0.0,0.0,0.0,5 *vna,2*vna,0.0,0.1*vna,0.25 *vna,0.75*vna,0.0,0.0])
#Sliders

pn.extension()
Rim4_tau_slider = pn.widgets.FloatSlider(
    name="Rim4 τ", start=0, end=10, step=0.01, value=0.2
)
Rim4_T_slider = pn.widgets.FloatSlider(
    name="Rim4 T", start=1, end=100, step=1, value=20
)
t_max_slider = pn.widgets.FloatSlider(
    name="t max",start=1, end=300, step=1, value=140
)
@pn.depends(
    Rim4_tau_slider.param.value,
    Rim4_T_slider.param.value,
    t_max_slider.param.value,
   
)
def Clb41Mut_plot(
    Rim4_tau=0.2,
    Rim4_T=20,
    t_max=200,
):
    args = (
        Rim4_tau,
        Rim4_T
    )

      # Integrate ODES
    t = np.linspace(0, t_max, 400)
    Odes = scipy.integrate.odeint(Clb41Mut_ODE, Odes_0, t, args=args)
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N  = Odes.transpose()
  
    # Set up plot
    p = bokeh.plotting.figure(
        frame_width=425,
        frame_height=350,
        x_axis_label="Time (minutes)",
        y_axis_label="Protein Concentration (a.u.)",
        x_range=[0, t_max],
    )

      # Populate glyphs
    #p.line(t, Clb1N/vna, line_width=2, color=colors[37], legend_label="Clb1")
    #p.line(t, Clb4N/vna, line_width=2, color=colors[20], legend_label="Clb4")
    p.line(t, Clb3N/vna, line_width=2, color=colors[72], legend_label="Clb3")
    #p.line(t, Ndt80N, line_width=2, color=colors[3], legend_label="Ndt80N")
    #p.line(t, Cdc20TN, line_width=2, color=colors[4], legend_label="Cdc20TN")
    #p.line(t, APCpN, line_width=2, color=colors[5], legend_label="APCpN")
    p.line(t, APCpCdc20N/vna, line_width=2, color=colors[9], legend_label="APCpCdc20")
    p.line(t, Cdc5AN/vna, line_width=2, color=colors[70], legend_label="Cdc5A")
    #p.line(t, Cdc5TN, line_width=2, color=colors[8], legend_label="Cdc5TN")
    #p.line(t, Ama1PN, line_width=2, color=colors[9], legend_label="Ama1PN")
    #p.line(t, Ama1N , line_width=2, color=colors[10], legend_label="Ama1N")
    p.line(t, (Clb1N+Clb3N+Clb4N)/vna, line_width=2, color=colors[11], legend_label="Clb Total")
    p.line(t,0.47,line_width=3,color=colors[11],line_dash='4 4')

    

    # Place the legend
    p.legend.location = "top_right"
    p.xaxis.axis_label_text_font_size = "14pt"
    p.yaxis.axis_label_text_font_size = "14pt"
    p.yaxis.major_label_text_font_size = '12pt'
    p.xaxis.major_label_text_font_size = '11pt'

    return p
    
widgets = pn.Column(
    pn.Spacer(height=10),
    Rim4_tau_slider,
    Rim4_T_slider,
    t_max_slider,
    width=150,
)

left_column = pn.Column(
    pn.Row(pn.Spacer(width=10)), Clb41Mut_plot,
)

# Final layout
pn.Row(left_column, pn.Spacer(width=20),widgets)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a8d02675-fffb-4e7e-92bd-135cd339d51f'>
#   <div id="f100fcb5-566b-41cb-a0a8-111a95fe58a8" data-root-id="a8d02675-fffb-4e7e-92bd-135cd339d51f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"2db51d4a-4e04-4229-9a85-5f285adbff3e":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"a8d02675-fffb-4e7e-92bd-135cd339d51f"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"523bf966-15a9-45bf-b35c-9ee7b9abd8da","attributes":{"plot_id":"a8d02675-fffb-4e7e-92bd-135cd339d51f","comm_id":"b0513ed0c427404bbd9328d4d53c79bd","client_comm_id":"94b5a6171cc746c48028761bdcaa4ccf"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"2db51d4a-4e04-4229-9a85-5f285adbff3e","roots":{"a8d02675-fffb-4e7e-92bd-135cd339d51f":"f100fcb5-566b-41cb-a0a8-111a95fe58a8"},"root_ids":["a8d02675-fffb-4e7e-92bd-135cd339d51f"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Row
#     [0] Column
#         [0] Row
#             [0] Spacer(width=10)
#         [1] ParamFunction(function, _pane=Bokeh, defer_load=False)
#     [1] Spacer(width=20)
#     [2] Column(width=150)
#         [0] Spacer(height=10)
#         [1] FloatSlider(end=10, name='Rim4 τ', step=0.01, value=0.2)
#         [2] FloatSlider(end=100, name='Rim4 T', start=1, step=1, value=20)
#         [3] FloatSlider(end=300, name='t max', start=1, step=1, value=140)

# %%
#----Clb1 + Clb3 mutant----

def Clb31Mut_ODE(Odes, t, Rim4_tau, Rim4_T):
    
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N = Odes

    # Compute dOdes/dt
    dClb1_dt = 0.0*(kClb1s*vna + kClb1sp * Ndt80N - (kClb1d +  kClb1dp*ivna * Ama1N + kClb1dpp*ivna * (Ama1N + Ama1PN) + kClb1Cdc20d*ivna*APCpCdc20N) * Clb1N)
    dClb4_dt = 1.0*(kClb4s*vna + kClb4sp * Ndt80N - (kClb4d +  kClb4dp*ivna * Ama1N + kClb4dpp*ivna * (Ama1N + Ama1PN) + kClb4Cdc20d*ivna*APCpCdc20N) * Clb4N)
    dClb3_dt = 0.0*(kClb3s*vna - (kClb3d  + (kClb3dp*ivna * Ama1N + kClb3dpp*ivna * (Ama1N + Ama1PN)) + kClb3Cdc20d*ivna*APCpCdc20N) * Clb3N + AlphaClb3*(vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25) + kClb3sp*(1 - Rim4(t,Rim4_tau, Rim4_T))* Ndt80N) 
    dNdt80_dt = 1.0*(kNdt80s*vna + kNdt80sp*Ndt80N*vna/(Jfunc(Ndt80N) + Ndt80N) - kNdt80d * Ndt80N - kNdt80dp*ivna*Ama1N* Ndt80N) 
    dCdc20T_dt = 1.0*(kCdc20s*vna + kCdc20sp * Ndt80N - kCdc20d*Cdc20TN - kCdc20dp* APCpCdc20N)
    dAPCp_dt = kApcClb*Clb4N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) + kApcClb*Clb1N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) - kApcp* vna*APCpN/(JApcp*vna + APCpN) + kApcClb*Clb3N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N))
    dAPCpCdc20_dt = kApcCdc20a*APCpN*(Cdc20TN - APCpCdc20N)/(JApcCdc20a*vna + Cdc20TN - APCpCdc20N) - kApcCdc20d*vna*APCpCdc20N/(JApcCdc20d*vna + APCpCdc20N) 
    dCdc5A_dt = 1.0*((kCdc5a + kCdc5ap *ivna* Clb1N + kCdc5ap *ivna* Clb4N)*(Cdc5TN - Cdc5AN) - kCdc5i*Cdc5AN - (kCdc5d + kCdc5dp* ivna*Ama1N + kCdc5dpp* ivna*(Ama1N + Ama1PN) ) * Cdc5AN) + kCdc5app *ivna* Clb3N*(Cdc5TN - Cdc5AN)
    dCdc5T_dt = 1.0*(kCdc5s*vna + kCdc5sp * Ndt80N - (kCdc5d + kCdc5dp * ivna*Ama1N + kCdc5dpp * ivna*(Ama1N + Ama1PN)) * Cdc5TN)
    dAma1P_dt = 1.0*((kAma1i + kAma1ip*ivna*Clb1N + kAma1ip*ivna*Clb4N + kAma1ip*ivna*Clb3N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - kAma1dp*Ama1PN)
    dAma1_dt = 1.0*(kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - (kAma1i + kAma1ip*ivna*Clb1N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb4N * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb3N * Ama1N*vna/(JAma1*vna + Ama1N) + kAma1s*vna - kAma1dp*Ama1N + AlphakAma1s*(1*vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25))
    
    # Return the result as a NumPy array
    return np.array([dClb1_dt,  dClb4_dt, dClb3_dt, dNdt80_dt, dCdc20T_dt, dAPCp_dt, dAPCpCdc20_dt, dCdc5A_dt,  dCdc5T_dt, dAma1P_dt, dAma1_dt])


# Initial condition
Odes_0 = np.array([0.0,0.12* vna,0.0,5 *vna,2*vna,0.0,0.1*vna,0.25 *vna,0.75*vna,0.0,0.0])
#Sliders

pn.extension()
Rim4_tau_slider = pn.widgets.FloatSlider(
    name="Rim4 τ", start=0, end=10, step=0.01, value=0.2
)
Rim4_T_slider = pn.widgets.FloatSlider(
    name="Rim4 T", start=1, end=100, step=1, value=20
)
t_max_slider = pn.widgets.FloatSlider(
    name="t max",start=1, end=300, step=1, value=140
)
@pn.depends(
    Rim4_tau_slider.param.value,
    Rim4_T_slider.param.value,
    t_max_slider.param.value,
   
)
def Clb31Mut_plot(
    Rim4_tau=0.2,
    Rim4_T=20,
    t_max=200,
):
    args = (
        Rim4_tau,
        Rim4_T
    )

      # Integrate ODES
    t = np.linspace(0, t_max, 400)
    Odes = scipy.integrate.odeint(Clb31Mut_ODE, Odes_0, t, args=args)
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N  = Odes.transpose()
  
    # Set up plot
    p = bokeh.plotting.figure(
        frame_width=425,
        frame_height=350,
        x_axis_label="Time (minutes)",
        y_axis_label="Protein Concentration (a.u.)",
        x_range=[0, t_max],
    )

      # Populate glyphs
    #p.line(t, Clb1N/vna, line_width=2, color=colors[37], legend_label="Clb1")
    p.line(t, Clb4N/vna, line_width=2, color=colors[20], legend_label="Clb4")
    #p.line(t, Clb3N/vna, line_width=2, color=colors[72], legend_label="Clb3")
    #p.line(t, Ndt80N, line_width=2, color=colors[3], legend_label="Ndt80N")
    #p.line(t, Cdc20TN, line_width=2, color=colors[4], legend_label="Cdc20TN")
    #p.line(t, APCpN, line_width=2, color=colors[5], legend_label="APCpN")
    p.line(t, APCpCdc20N/vna, line_width=2, color=colors[9], legend_label="APCpCdc20")
    p.line(t, Cdc5AN/vna, line_width=2, color=colors[70], legend_label="Cdc5A")
    #p.line(t, Cdc5TN, line_width=2, color=colors[8], legend_label="Cdc5TN")
    #p.line(t, Ama1PN, line_width=2, color=colors[9], legend_label="Ama1PN")
    #p.line(t, Ama1N , line_width=2, color=colors[10], legend_label="Ama1N")
    p.line(t, (Clb1N+Clb3N+Clb4N)/vna, line_width=2, color=colors[11], legend_label="Clb Total")
    p.line(t,0.47,line_width=3,color=colors[11],line_dash='4 4')

    

    # Place the legend
    p.legend.location = "top_right"
    p.xaxis.axis_label_text_font_size = "14pt"
    p.yaxis.axis_label_text_font_size = "14pt"
    p.yaxis.major_label_text_font_size = '12pt'
    p.xaxis.major_label_text_font_size = '11pt'

    return p
    
widgets = pn.Column(
    pn.Spacer(height=10),
    Rim4_tau_slider,
    Rim4_T_slider,
    t_max_slider,
    width=150,
)

left_column = pn.Column(
    pn.Row(pn.Spacer(width=10)), Clb31Mut_plot,
)

# Final layout
pn.Row(left_column, pn.Spacer(width=20),widgets)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='af76864b-9f13-4070-b22c-af8f8618036f'>
#   <div id="ce68c885-cbf9-4bb1-89c1-d5945638cf63" data-root-id="af76864b-9f13-4070-b22c-af8f8618036f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"e735b4cf-9375-4c40-82aa-301901c90587":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"af76864b-9f13-4070-b22c-af8f8618036f"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"33cfaaa8-2698-4de7-92a8-18e0f6d4c3cd","attributes":{"plot_id":"af76864b-9f13-4070-b22c-af8f8618036f","comm_id":"b6fc19fa1c42493987744ffcd2825dc6","client_comm_id":"97853b4218664341be5bc7809b9510f3"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"e735b4cf-9375-4c40-82aa-301901c90587","roots":{"af76864b-9f13-4070-b22c-af8f8618036f":"ce68c885-cbf9-4bb1-89c1-d5945638cf63"},"root_ids":["af76864b-9f13-4070-b22c-af8f8618036f"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Row
#     [0] Column
#         [0] Row
#             [0] Spacer(width=10)
#         [1] ParamFunction(function, _pane=Bokeh, defer_load=False)
#     [1] Spacer(width=20)
#     [2] Column(width=150)
#         [0] Spacer(height=10)
#         [1] FloatSlider(end=10, name='Rim4 τ', step=0.01, value=0.2)
#         [2] FloatSlider(end=100, name='Rim4 T', start=1, step=1, value=20)
#         [3] FloatSlider(end=300, name='t max', start=1, step=1, value=140)

# %%
#----Clb4 + Clb3 mutant----

def Clb34Mut_ODE(Odes, t, Rim4_tau, Rim4_T):
    
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N = Odes

    # Compute dOdes/dt
    dClb1_dt = 1.0*(kClb1s*vna + kClb1sp * Ndt80N - (kClb1d +  kClb1dp*ivna * Ama1N + kClb1dpp*ivna * (Ama1N + Ama1PN) + kClb1Cdc20d*ivna*APCpCdc20N) * Clb1N)
    dClb4_dt = 0.0*(kClb4s*vna + kClb4sp * Ndt80N - (kClb4d +  kClb4dp*ivna * Ama1N + kClb4dpp*ivna * (Ama1N + Ama1PN) + kClb4Cdc20d*ivna*APCpCdc20N) * Clb4N)
    dClb3_dt = 0.0*(kClb3s*vna - (kClb3d  + (kClb3dp*ivna * Ama1N + kClb3dpp*ivna * (Ama1N + Ama1PN)) + kClb3Cdc20d*ivna*APCpCdc20N) * Clb3N + AlphaClb3*(vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25) + kClb3sp*(1 - Rim4(t,Rim4_tau, Rim4_T))* Ndt80N) 
    dNdt80_dt = 1.0*(kNdt80s*vna + kNdt80sp*Ndt80N*vna/(Jfunc(Ndt80N) + Ndt80N) - kNdt80d * Ndt80N - kNdt80dp*ivna*Ama1N* Ndt80N) 
    dCdc20T_dt = 1.0*(kCdc20s*vna + kCdc20sp * Ndt80N - kCdc20d*Cdc20TN - kCdc20dp* APCpCdc20N)
    dAPCp_dt = kApcClb*Clb4N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) + kApcClb*Clb1N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) - kApcp* vna*APCpN/(JApcp*vna + APCpN) + kApcClb*Clb3N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N))
    dAPCpCdc20_dt = kApcCdc20a*APCpN*(Cdc20TN - APCpCdc20N)/(JApcCdc20a*vna + Cdc20TN - APCpCdc20N) - kApcCdc20d*vna*APCpCdc20N/(JApcCdc20d*vna + APCpCdc20N) 
    dCdc5A_dt = 1.0*((kCdc5a + kCdc5ap *ivna* Clb1N + kCdc5ap *ivna* Clb4N)*(Cdc5TN - Cdc5AN) - kCdc5i*Cdc5AN - (kCdc5d + kCdc5dp* ivna*Ama1N + kCdc5dpp* ivna*(Ama1N + Ama1PN) ) * Cdc5AN) + kCdc5app *ivna* Clb3N*(Cdc5TN - Cdc5AN)
    dCdc5T_dt = 1.0*(kCdc5s*vna + kCdc5sp * Ndt80N - (kCdc5d + kCdc5dp * ivna*Ama1N + kCdc5dpp * ivna*(Ama1N + Ama1PN)) * Cdc5TN)
    dAma1P_dt = 1.0*((kAma1i + kAma1ip*ivna*Clb1N + kAma1ip*ivna*Clb4N + kAma1ip*ivna*Clb3N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - kAma1dp*Ama1PN)
    dAma1_dt = 1.0*(kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - (kAma1i + kAma1ip*ivna*Clb1N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb4N * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb3N * Ama1N*vna/(JAma1*vna + Ama1N) + kAma1s*vna - kAma1dp*Ama1N + AlphakAma1s*(1*vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25))
    
    # Return the result as a NumPy array
    return np.array([dClb1_dt,  dClb4_dt, dClb3_dt, dNdt80_dt, dCdc20T_dt, dAPCp_dt, dAPCpCdc20_dt, dCdc5A_dt,  dCdc5T_dt, dAma1P_dt, dAma1_dt])


# Initial condition
Odes_0 = np.array([1.125* vna,0.0,0.0,5 *vna,2*vna,0.0,0.1*vna,0.25 *vna,0.75*vna,0.0,0.0])
#Sliders

pn.extension()
Rim4_tau_slider = pn.widgets.FloatSlider(
    name="Rim4 τ", start=0, end=10, step=0.01, value=0.2
)
Rim4_T_slider = pn.widgets.FloatSlider(
    name="Rim4 T", start=1, end=100, step=1, value=20
)
t_max_slider = pn.widgets.FloatSlider(
    name="t max",start=1, end=300, step=1, value=140
)
@pn.depends(
    Rim4_tau_slider.param.value,
    Rim4_T_slider.param.value,
    t_max_slider.param.value,
   
)
def Clb34Mut_plot(
    Rim4_tau=0.2,
    Rim4_T=20,
    t_max=200,
):
    args = (
        Rim4_tau,
        Rim4_T
    )

      # Integrate ODES
    t = np.linspace(0, t_max, 400)
    Odes = scipy.integrate.odeint(Clb34Mut_ODE, Odes_0, t, args=args)
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N  = Odes.transpose()
  
    # Set up plot
    p = bokeh.plotting.figure(
        frame_width=425,
        frame_height=350,
        x_axis_label="Time (minutes)",
        y_axis_label="Protein Concentration (a.u.)",
        x_range=[0, t_max],
    )

      # Populate glyphs
    p.line(t, Clb1N/vna, line_width=2, color=colors[37], legend_label="Clb1")
    #p.line(t, Clb4N/vna, line_width=2, color=colors[20], legend_label="Clb4")
    #p.line(t, Clb3N/vna, line_width=2, color=colors[72], legend_label="Clb3")
    #p.line(t, Ndt80N, line_width=2, color=colors[3], legend_label="Ndt80N")
    #p.line(t, Cdc20TN, line_width=2, color=colors[4], legend_label="Cdc20TN")
    #p.line(t, APCpN, line_width=2, color=colors[5], legend_label="APCpN")
    p.line(t, APCpCdc20N/vna, line_width=2, color=colors[9], legend_label="APCpCdc20N")
    p.line(t, Cdc5AN/vna, line_width=2, color=colors[70], legend_label="Cdc5AN")
    #p.line(t, Cdc5TN, line_width=2, color=colors[8], legend_label="Cdc5TN")
    #p.line(t, Ama1PN, line_width=2, color=colors[9], legend_label="Ama1PN")
    #p.line(t, Ama1N , line_width=2, color=colors[10], legend_label="Ama1N")
    p.line(t, (Clb1N+Clb3N+Clb4N)/vna, line_width=2, color=colors[11], legend_label="Clb Total")
    p.line(t,0.47,line_width=3,color=colors[11],line_dash='4 4')

    

    # Place the legend
    p.legend.location = "top_right"
    p.xaxis.axis_label_text_font_size = "14pt"
    p.yaxis.axis_label_text_font_size = "14pt"
    p.yaxis.major_label_text_font_size = '12pt'
    p.xaxis.major_label_text_font_size = '11pt'

    return p
    
widgets = pn.Column(
    pn.Spacer(height=10),
    Rim4_tau_slider,
    Rim4_T_slider,
    t_max_slider,
    width=150,
)

left_column = pn.Column(
    pn.Row(pn.Spacer(width=10)), Clb34Mut_plot,
)

# Final layout
pn.Row(left_column, pn.Spacer(width=20),widgets)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='aa05073c-12b1-4716-a562-166e976e6115'>
#   <div id="ea91af11-d376-422e-a47c-d52d0eff4a59" data-root-id="aa05073c-12b1-4716-a562-166e976e6115" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"a0e02c06-6cd3-4ad1-8bc1-30edc6bd82bc":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"aa05073c-12b1-4716-a562-166e976e6115"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"0a2e7cf5-1133-47df-b7d4-dcf13e243115","attributes":{"plot_id":"aa05073c-12b1-4716-a562-166e976e6115","comm_id":"7a9f32347735405390a7cb75bc73b3de","client_comm_id":"3db6e68365b04f6c8f370a4938ed36c9"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"a0e02c06-6cd3-4ad1-8bc1-30edc6bd82bc","roots":{"aa05073c-12b1-4716-a562-166e976e6115":"ea91af11-d376-422e-a47c-d52d0eff4a59"},"root_ids":["aa05073c-12b1-4716-a562-166e976e6115"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Row
#     [0] Column
#         [0] Row
#             [0] Spacer(width=10)
#         [1] ParamFunction(function, _pane=Bokeh, defer_load=False)
#     [1] Spacer(width=20)
#     [2] Column(width=150)
#         [0] Spacer(height=10)
#         [1] FloatSlider(end=10, name='Rim4 τ', step=0.01, value=0.2)
#         [2] FloatSlider(end=100, name='Rim4 T', start=1, step=1, value=20)
#         [3] FloatSlider(end=300, name='t max', start=1, step=1, value=140)

# %%
#----ClbTotal mutant----

def ClbMut_ODE(Odes, t, Rim4_tau, Rim4_T):
    
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N = Odes

    # Compute dOdes/dt
    dClb1_dt = 0.0*(kClb1s*vna + kClb1sp * Ndt80N - (kClb1d +  kClb1dp*ivna * Ama1N + kClb1dpp*ivna * (Ama1N + Ama1PN) + kClb1Cdc20d*ivna*APCpCdc20N) * Clb1N)
    dClb4_dt = 0.0*(kClb4s*vna + kClb4sp * Ndt80N - (kClb4d +  kClb4dp*ivna * Ama1N + kClb4dpp*ivna * (Ama1N + Ama1PN) + kClb4Cdc20d*ivna*APCpCdc20N) * Clb4N)
    dClb3_dt = 0.0*(kClb3s*vna - (kClb3d  + (kClb3dp*ivna * Ama1N + kClb3dpp*ivna * (Ama1N + Ama1PN)) + kClb3Cdc20d*ivna*APCpCdc20N) * Clb3N + AlphaClb3*(vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25) + kClb3sp*(1 - Rim4(t,Rim4_tau, Rim4_T))* Ndt80N) 
    dNdt80_dt = 1.0*(kNdt80s*vna + kNdt80sp*Ndt80N*vna/(Jfunc(Ndt80N) + Ndt80N) - kNdt80d * Ndt80N - kNdt80dp*ivna*Ama1N* Ndt80N) 
    dCdc20T_dt = 1.0*(kCdc20s*vna + kCdc20sp * Ndt80N - kCdc20d*Cdc20TN - kCdc20dp* APCpCdc20N)
    dAPCp_dt = kApcClb*Clb4N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) + kApcClb*Clb1N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N)) - kApcp* vna*APCpN/(JApcp*vna + APCpN) + kApcClb*Clb3N * (APCtot - APCpN - APCpCdc20N)/(JApcClb*vna + (APCtot - APCpN - APCpCdc20N))
    dAPCpCdc20_dt = kApcCdc20a*APCpN*(Cdc20TN - APCpCdc20N)/(JApcCdc20a*vna + Cdc20TN - APCpCdc20N) - kApcCdc20d*vna*APCpCdc20N/(JApcCdc20d*vna + APCpCdc20N) 
    dCdc5A_dt = 1.0*((kCdc5a + kCdc5ap *ivna* Clb1N + kCdc5ap *ivna* Clb4N)*(Cdc5TN - Cdc5AN) - kCdc5i*Cdc5AN - (kCdc5d + kCdc5dp* ivna*Ama1N + kCdc5dpp* ivna*(Ama1N + Ama1PN) ) * Cdc5AN) + kCdc5app *ivna* Clb3N*(Cdc5TN - Cdc5AN)
    dCdc5T_dt = 1.0*(kCdc5s*vna + kCdc5sp * Ndt80N - (kCdc5d + kCdc5dp * ivna*Ama1N + kCdc5dpp * ivna*(Ama1N + Ama1PN)) * Cdc5TN)
    dAma1P_dt = 1.0*((kAma1i + kAma1ip*ivna*Clb1N + kAma1ip*ivna*Clb4N + kAma1ip*ivna*Clb3N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - kAma1dp*Ama1PN)
    dAma1_dt = 1.0*(kAma1a * Ama1PN*vna/(JAma1*vna + Ama1PN) - (kAma1i + kAma1ip*ivna*Clb1N) * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb4N * Ama1N*vna/(JAma1*vna + Ama1N) - kAma1ip*ivna*Clb3N * Ama1N*vna/(JAma1*vna + Ama1N) + kAma1s*vna - kAma1dp*Ama1N + AlphakAma1s*(1*vna - Rim4(t,Rim4_tau, Rim4_T)*vna)*math.exp(-(t - Rim4_T)/25))
    
    # Return the result as a NumPy array
    return np.array([dClb1_dt,  dClb4_dt, dClb3_dt, dNdt80_dt, dCdc20T_dt, dAPCp_dt, dAPCpCdc20_dt, dCdc5A_dt,  dCdc5T_dt, dAma1P_dt, dAma1_dt])


# Initial condition
Odes_0 = np.array([0.0,0.0,0.0,5 *vna,2*vna,0.0,0.1*vna,0.25 *vna,0.75*vna,0.0,0.0])

#Sliders

pn.extension()
Rim4_tau_slider = pn.widgets.FloatSlider(
    name="Rim4 τ", start=0, end=10, step=0.01, value=0.2
)
Rim4_T_slider = pn.widgets.FloatSlider(
    name="Rim4 T", start=1, end=100, step=1, value=20
)
t_max_slider = pn.widgets.FloatSlider(
    name="t max",start=1, end=300, step=1, value=140
)
@pn.depends(
    Rim4_tau_slider.param.value,
    Rim4_T_slider.param.value,
    t_max_slider.param.value,
   
)

def ClbMut_plot(
    Rim4_tau=0.2,
    Rim4_T=20,
    t_max=200,
):
    args = (
        Rim4_tau,
        Rim4_T
    )

      # Integrate ODES
    t = np.linspace(0, t_max, 400)
    Odes = scipy.integrate.odeint(ClbMut_ODE, Odes_0, t, args=args)
    Clb1N,  Clb4N, Clb3N, Ndt80N, Cdc20TN, APCpN, APCpCdc20N, Cdc5AN, Cdc5TN, Ama1PN, Ama1N  = Odes.transpose()
  
    # Set up plot
    p = bokeh.plotting.figure(
        frame_width=425,
        frame_height=350,
        x_axis_label="Time (minutes)",
        y_axis_label="Protein Concentration (a.u.)",
        x_range=[0, t_max],
    )

      # Populate glyphs
    #p.line(t, Clb1N/vna, line_width=2, color=colors[0], legend_label="Clb1")
    #p.line(t, Clb4N/vna, line_width=2, color=colors[1], legend_label="Clb4")
    #p.line(t, Clb3N/vna, line_width=2, color=colors[2], legend_label="Clb3")
    p.line(t, Ndt80N, line_width=2, color=colors[3], legend_label="Ndt80N")
    p.line(t, Cdc20TN, line_width=2, color=colors[4], legend_label="Cdc20TN")
    p.line(t, APCpN, line_width=2, color=colors[5], legend_label="APCpN")
    #p.line(t, APCpCdc20N/vna, line_width=2, color=colors[6], legend_label="APCpCdc20N")
    #p.line(t, Cdc5AN/vna, line_width=2, color=colors[7], legend_label="Cdc5AN")
    p.line(t, Cdc5TN, line_width=2, color=colors[8], legend_label="Cdc5TN")
    #p.line(t, Ama1PN, line_width=2, color=colors[9], legend_label="Ama1PN")
    p.line(t, Ama1N , line_width=2, color=colors[10], legend_label="Ama1N")
    #p.line(t, (Clb1N+Clb3N+Clb4N)/vna, line_width=2, color=colors[11], legend_label="Clb Total")

    

    # Place the legend
    p.legend.location = "top_right"



    return p
    
widgets = pn.Column(
    pn.Spacer(height=10),
    Rim4_tau_slider,
    Rim4_T_slider,
    t_max_slider,
    width=150,
)

left_column = pn.Column(
    pn.Row(pn.Spacer(width=10)), ClbMut_plot,
)

# Final layout
pn.Row(left_column, pn.Spacer(width=20),widgets)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='50b82733-15ff-4184-80a6-9524c9b5a553'>
#   <div id="b08c9b1d-7724-4c2b-8ae3-d4a09418936a" data-root-id="50b82733-15ff-4184-80a6-9524c9b5a553" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"910f520c-a50a-4472-b155-a016c8e25b8c":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"50b82733-15ff-4184-80a6-9524c9b5a553"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"264a59c1-e581-496a-b8b9-08dbbb084842","attributes":{"plot_id":"50b82733-15ff-4184-80a6-9524c9b5a553","comm_id":"a5f7fc6f42e1426489837d607174bfc7","client_comm_id":"90b1d613f828428f8b4300957c7c908c"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"910f520c-a50a-4472-b155-a016c8e25b8c","roots":{"50b82733-15ff-4184-80a6-9524c9b5a553":"b08c9b1d-7724-4c2b-8ae3-d4a09418936a"},"root_ids":["50b82733-15ff-4184-80a6-9524c9b5a553"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Row
#     [0] Column
#         [0] Row
#             [0] Spacer(width=10)
#         [1] ParamFunction(function, _pane=Bokeh, defer_load=False)
#     [1] Spacer(width=20)
#     [2] Column(width=150)
#         [0] Spacer(height=10)
#         [1] FloatSlider(end=10, name='Rim4 τ', step=0.01, value=0.2)
#         [2] FloatSlider(end=100, name='Rim4 T', start=1, step=1, value=20)
#         [3] FloatSlider(end=300, name='t max', start=1, step=1, value=140)
